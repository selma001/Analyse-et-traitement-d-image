# %%
import numpy as np
import cv2
import matplotlib.pyplot as plt

# %%
image = cv2.imread('image2.png', cv2.IMREAD_GRAYSCALE)
taille = (25,25)

blurred_image = cv2.GaussianBlur(image, taille, 5)
plt.imshow(blurred_image, cmap='gray'), plt.title('Blurred Image')
plt.show()
